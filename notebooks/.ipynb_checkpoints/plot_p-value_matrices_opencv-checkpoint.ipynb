# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pylab as plt

# %%
pm_labels = np.arange(0.1, 2.1, 0.1)
pm_labels = np.round(pm_labels, 1)

# %%
metric = 'acc'
clf = 'svm'

file = metric + '_p_value_matrix_' + clf + '_opencv.xlsx'
name = 'm' + metric + '_' + clf + '_opencv'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()
# Out:
#           0.001     0.002     0.003     0.004     0.005     0.006     0.007  \
# 0.001  1.000000  0.760552  0.753245  1.000000  0.179170  0.196189  0.666558
# 0.002  0.760552  1.000000  1.000000  0.751311  0.291636  0.317002  0.900518
# 0.003  0.753245  1.000000  1.000000  0.743095  0.276138  0.301167  0.897229
# 0.004  1.000000  0.751311  0.743095  1.000000  0.162385  0.178588  0.653846
# 0.005  0.179170  0.291636  0.276138  0.162385  1.000000  0.949862  0.347001
# 0.006  0.196189  0.317002  0.301167  0.178588  0.949862  1.000000  0.376127
# 0.007  0.666558  0.900518  0.897229  0.653846  0.347001  0.376127  1.000000
# 0.008  0.356473  0.532335  0.518825  0.337278  0.660634  0.704367  0.613631
# 0.009  0.807937  0.950820  0.949233  0.800481  0.265734  0.289293  0.851723
# 0.010  0.950184  0.703450  0.693786  0.948092  0.143799  0.158437  0.607958
# 0.011  0.666558  0.900518  0.897229  0.653846  0.347001  0.376127  1.000000
# 0.012  1.000000  0.756063  0.748323  1.000000  0.170870  0.187499  0.660380
# 0.013  0.805056  0.573009  0.560274  0.797246  0.103056  0.113929  0.486419
# 0.014  0.361028  0.216848  0.202322  0.342230  0.022415  0.025091  0.170114
# 0.015  0.710610  0.489952  0.475518  0.699276  0.078598  0.087173  0.409728
# 0.016  0.853854  0.618129  0.606576  0.848004  0.118772  0.131023  0.528997
# 0.017  0.451115  0.655050  0.643886  0.432113  0.521637  0.560739  0.746954
# 0.018  0.106772  0.054403  0.047832  0.094927  0.003642  0.004096  0.039626
# 0.019  0.011271  0.004088  0.003054  0.008460  0.000100  0.000112  0.002521
# 0.020  0.082994  0.038317  0.032281  0.071065  0.001749  0.001976  0.026500
#
#           0.008     0.009     0.010     0.011     0.012     0.013     0.014  \
# 0.001  0.356473  0.807937  0.950184  0.666558  1.000000  0.805056  0.361028
# 0.002  0.532335  0.950820  0.703450  0.900518  0.756063  0.573009  0.216848
# 0.016  0.849424  1.000000  0.334984  0.141570  0.016044  0.112933
# 0.017  0.243788  0.334984  1.000000  0.016768  0.000700  0.009699
# 0.018  0.192572  0.141570  0.016768  1.000000  0.413559  1.000000
# 0.019  0.024995  0.016044  0.000700  0.413559  1.000000  0.378452
# 0.020  0.159492  0.112933  0.009699  1.000000  0.378452  1.000000

# %%
metric = 'auc'
clf = 'svm'

file = metric + '_p_value_matrix_' + clf + '_opencv.xlsx'
name = 'm' + metric + '_' + clf + '_opencv'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'acc'
clf = 'knn'

file = metric + '_p_value_matrix_' + clf + '_opencv.xlsx'
name = 'm' + metric + '_' + clf + '_opencv'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'auc'
clf = 'knn'

file = metric + '_p_value_matrix_' + clf + '_opencv.xlsx'
name = 'm' + metric + '_' + clf + '_opencv'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'acc'
clf = 'ann'

file = metric + '_p_value_matrix_' + clf + '_opencv.xlsx'
name = 'm' + metric + '_' + clf + '_opencv'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'auc'
clf = 'ann'

file = metric + '_p_value_matrix_' + clf + '_opencv.xlsx'
name = 'm' + metric + '_' + clf + '_opencv'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
sb.palplot(sb.dark_palette((1, 1, 1), n_colors=2))
