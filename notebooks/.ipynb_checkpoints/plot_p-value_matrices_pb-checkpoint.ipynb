# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pylab as plt

# %%
pm_labels = np.arange(0.1, 2.1, 0.1)
pm_labels = np.round(pm_labels, 1)

# %%
metric = 'acc'
clf = 'svm'

file = metric + '_p_value_matrix_' + clf + '_pb.xlsx'
name = 'm' + metric + '_' + clf + '_pb'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()
# Out:
#           0.001     0.002     0.003     0.004     0.005     0.006     0.007  \
# 0.001  1.000000  0.191544  0.630937  0.715969  0.902918  0.091311  0.464650
# 0.002  0.191544  1.000000  0.392125  0.084726  0.136859  0.677315  0.534521
# 0.003  0.630937  0.392125  1.000000  0.382447  0.530118  0.208318  0.801678
# 0.004  0.715969  0.084726  0.382447  1.000000  0.799567  0.034888  0.254071
# 0.005  0.902918  0.136859  0.530118  0.799567  1.000000  0.059957  0.371835
# 0.006  0.091311  0.677315  0.208318  0.034888  0.059957  1.000000  0.300867
# 0.007  0.464650  0.534521  0.801678  0.254071  0.371835  0.300867  1.000000
# 0.008  0.283956  0.808169  0.539980  0.138262  0.213708  0.512454  0.708697
# 0.009  0.079064  0.664618  0.189605  0.027764  0.049604  1.000000  0.280100
# 0.010  0.024909  0.351561  0.069602  0.006826  0.013424  0.625832  0.111465
# 0.011  0.015190  0.262663  0.044916  0.003762  0.007673  0.501660  0.074124
# 0.012  0.105999  0.799117  0.247666  0.038418  0.067944  0.851654  0.360013
# 0.013  0.042033  0.487476  0.111583  0.012502  0.023891  0.804464  0.173647
# 0.014  0.003932  0.103214  0.012847  0.000809  0.001750  0.235353  0.022415
# 0.015  0.004663  0.116053  0.015039  0.000985  0.002113  0.258909  0.026056
# 0.016  0.000019  0.001987  0.000084  0.000002  0.000005  0.008388  0.000171
# 0.017  0.000159  0.011405  0.000656  0.000018  0.000047  0.039111  0.001296
# 0.018  0.001038  0.045632  0.003874  0.000157  0.000375  0.125049  0.007242
# 0.019  0.004923  0.131887  0.016358  0.000968  0.002136  0.294812  0.028718
# 0.020  0.003461  0.103810  0.011812  0.000643  0.001445  0.243148  0.021044
#
#           0.008     0.009     0.010     0.011     0.012     0.013     0.014  \
# 0.001  0.283956  0.079064  0.024909  0.015190  0.105999  0.042033  0.003932
# 0.002  0.808169  0.664618  0.351561  0.262663  0.799117  0.487476  0.103214
# 0.016  0.118370  1.000000  0.496907  0.213278  0.081142  0.106163
# 0.017  0.350770  0.496907  1.000000  0.561104  0.271346  0.333116
# 0.018  0.706176  0.213278  0.561104  1.000000  0.600710  0.695545
# 0.019  0.899693  0.081142  0.271346  0.600710  1.000000  0.895873
# 0.020  1.000000  0.106163  0.333116  0.695545  0.895873  1.000000

# %%
metric = 'auc'
clf = 'svm'

file = metric + '_p_value_matrix_' + clf + '_pb.xlsx'
name = 'm' + metric + '_' + clf + '_pb'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'acc'
clf = 'knn'

file = metric + '_p_value_matrix_' + clf + '_pb.xlsx'
name = 'm' + metric + '_' + clf + '_pb'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'auc'
clf = 'knn'

file = metric + '_p_value_matrix_' + clf + '_pb.xlsx'
name = 'm' + metric + '_' + clf + '_pb'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'acc'
clf = 'ann'

file = metric + '_p_value_matrix_' + clf + '_pb.xlsx'
name = 'm' + metric + '_' + clf + '_pb'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
metric = 'auc'
clf = 'ann'

file = metric + '_p_value_matrix_' + clf + '_pb.xlsx'
name = 'm' + metric + '_' + clf + '_pb'

excel = pd.ExcelFile(file)
p_values = excel.parse('Sheet1', index_col=0)

sb.heatmap(p_values, xticklabels=pm_labels, yticklabels=pm_labels, center=0.05, cmap=sb.dark_palette((1, 1, 1), n_colors=2), square=True, cbar=False)

plt.savefig(name, dpi=150)

plt.show()

# %%
sb.palplot(sb.dark_palette((1, 1, 1), n_colors=2))
