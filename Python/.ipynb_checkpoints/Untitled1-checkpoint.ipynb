# %%
import cv2
import numpy as np
from PIL import Image

# %%
img = cv2.imread('C55_97LOROI.jpg')
# img = cv2.resize(img, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
canvas = np.zeros(img.shape, np.uint8)
_, thresh = cv2.threshold(img, 20, 255, cv2.THRESH_BINARY)
im2, contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

def max_area_contour(contours):
    cnt = contours[0]
    max_area = cv2.contourArea(cnt)

    for cont in contours:
        if cv2.contourArea(cont) > max_area:
            cnt = cont
            max_area = cv2.contourArea(cont)
    return cnt
# Out:
# <PIL.Image.Image image mode=L size=1751x1751 at 0x21931E94048>
